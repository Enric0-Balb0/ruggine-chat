# %%
import matplotlib.pyplot as plt
import pandas as pd
import matplotlib.dates as mdates

# %%
# Dati benchmark creazione messaggi
casi = [
    (10, 10, 1),
    (10, 10, 10),
    (100, 10, 10),
    (100, 10, 100),
    (1000, 10, 10),
]

tempo_medio_ms = [26.098797, 5.639972, 4.362299, 2.739854, 3.73231]
msg_s = [38.32, 177.31, 229.24, 364.98, 267.93]

# Etichette leggibili
etichette = [f"G={g}, U={u}, M={m}" for g, u, m in casi]

# Grafico
fig, ax1 = plt.subplots(figsize=(10,6))

# Primo asse: tempo medio per messaggio
ax1.plot(etichette, tempo_medio_ms, marker="o", linewidth=2, label="Tempo medio per messaggio (ms)", color="blue")
ax1.set_ylabel("Tempo medio per messaggio (ms)", color="blue")
ax1.tick_params(axis='y', labelcolor="blue")

# Secondo asse: Msg/s
ax2 = ax1.twinx()
ax2.plot(etichette, msg_s, marker="s", linewidth=2, label="Msg/s", color="orange")
ax2.set_ylabel("Messaggi/s", color="orange")
ax2.tick_params(axis='y', labelcolor="orange")

# Titolo e griglia
plt.title("Benchmark Creazione Messaggi")
ax1.grid(True, linestyle="--", alpha=0.6)

# Legenda combinata
lines1, labels1 = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax1.legend(lines1 + lines2, labels1 + labels2, loc="best")

# Etichette X ruotate e layout corretto
ax1.set_xticks(range(len(etichette)))
ax1.set_xlabel("Configurazione (Gruppi, Utenti per gruppo, Messaggi per utente)")

fig.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Dati benchmark lettura + marcatura
# Tripletta (gruppi, utenti_per_gruppo, messaggi_per_utente)
casi = [
    (10, 10, 10),
    (50, 10, 10),
    (100, 10, 10),
]

# Lettura messaggi
letture_s = [11.25, 11.16, 11.11]
tempo_medio_lettura_ms = [88.8607, 89.600485, 90.019327]

# Marcatura come letti
mark_reads_s = [668.52, 588.04, 581.44]
tempo_medio_mark_ms = [1.495839, 1.700567, 1.71987]

# Etichette per ogni caso (tripletta)
etichette = [f"G={g}, U={u}, M={m}" for g,u,m in casi]

# Creazione grafico
fig, ax1 = plt.subplots(figsize=(10,6))

# Lettura messaggi
ax1.plot(etichette, letture_s, marker="o", label="Letture/s", linewidth=2)
ax1.set_ylabel("Letture/s", color="blue")
ax1.tick_params(axis='y', labelcolor="blue")

# Secondo asse Y per la marcatura
ax2 = ax1.twinx()
ax2.plot(etichette, mark_reads_s, marker="s", color="orange", label="Mark reads/s", linewidth=2)
ax2.set_ylabel("Mark reads/s", color="orange")
ax2.tick_params(axis='y', labelcolor="orange")

# Titolo
plt.title("Benchmark Lettura Messaggi Non Letti & Marcatura messaggi")

# Griglia
ax1.grid(True, linestyle="--", alpha=0.6)

# Legenda combinata
lines, labels = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax1.legend(lines + lines2, labels + labels2, loc="best")


ax1.set_xlabel("Configurazione (Gruppi, Utenti per gruppo, Messaggi per utente)")

plt.show()

# %%
# Dati benchmark inviti/accettazioni
casi = [
    (10, 10, 100),    # (gruppi, utenti_per_gruppo, utenti_totali)
    (100, 10, 1000),
    (500, 10, 5000),
    (1000, 10, 10000),
]

inviti_s = [355.81, 497.37, 513.22, 532.26]
accettazioni_s = [229.10, 347.45, 359.98, 468.22]

# Etichette leggibili
etichette = [f"G={g}, U={u}, Tot={t}" for g,u,t in casi]

# Grafico
plt.figure(figsize=(10,6))
plt.plot(etichette, inviti_s, marker="o", linewidth=2, label="Inviti/s")
plt.plot(etichette, accettazioni_s, marker="s", linewidth=2, label="Accettazioni/s")

plt.title("Benchmark Inviti & Accettazioni")
plt.xlabel("Configurazione (Gruppi, Utenti per gruppo, Utenti totali)")
plt.ylabel("Operazioni al secondo")
plt.grid(True, linestyle="--", alpha=0.6)
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt

# Dati benchmark lettura messaggi paginati
casi = [
    (10, 10, 10),
    (10, 10, 100),
    (10, 10, 1000),
]

tempo_pagina_ms = [3.815037, 3.73314, 3.556840]
letture_s = [262.12, 26.79, 2.81]

# Etichette leggibili
etichette = [f"G={g}, U={u}, M={m}" for g,u,m in casi]

# Grafico
fig, ax1 = plt.subplots(figsize=(10,6))

# Primo asse: tempo medio per pagina
ax1.plot(etichette, tempo_pagina_ms, marker="o", linewidth=2, label="Tempo medio per pagina (ms)", color="blue")
ax1.set_ylabel("Tempo medio per pagina (ms)", color="blue")
ax1.tick_params(axis='y', labelcolor="blue")

# Secondo asse: letture/s
ax2 = ax1.twinx()
ax2.plot(etichette, letture_s, marker="s", linewidth=2, label="Letture/s", color="orange")
ax2.set_ylabel("Letture/s", color="orange")
ax2.tick_params(axis='y', labelcolor="orange")

# Titolo e griglia
plt.title("Benchmark Lettura Messaggi Paginati")
ax1.grid(True, linestyle="--", alpha=0.6)

# Legenda combinata
lines1, labels1 = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax1.legend(lines1 + lines2, labels1 + labels2, loc="best")

ax1.set_xlabel("Configurazione (Gruppi, Utenti per gruppo, Messaggi per utente nel gruppo)")
plt.show()

# %%
import matplotlib.pyplot as plt

# Dati benchmark FIND_CONNECTED_USERS_ONLINE
casi = [
    (10, 10, 100),
    (100, 10, 1000),
    (1000, 10, 10000),
    (100, 100, 10000),
]

tempo_richiesta_ms = [4.081897, 3.340271, 4.347024, 4.892464]
richieste_s = [244.98, 299.38, 230.04, 204.40]

# Etichette leggibili
etichette = [f"G={g}, U={u}, T={t}" for g, u, t in casi]

# Grafico
fig, ax1 = plt.subplots(figsize=(10,6))

# Primo asse: tempo medio per richiesta
ax1.plot(etichette, tempo_richiesta_ms, marker="o", linewidth=2, label="Tempo medio per richiesta (ms)", color="blue")
ax1.set_ylabel("Tempo medio per richiesta (ms)", color="blue")
ax1.tick_params(axis='y', labelcolor="blue")

# Secondo asse: richieste/s
ax2 = ax1.twinx()
ax2.plot(etichette, richieste_s, marker="s", linewidth=2, label="Richieste/s", color="orange")
ax2.set_ylabel("Richieste/s", color="orange")
ax2.tick_params(axis='y', labelcolor="orange")

# Titolo e griglia
plt.title("Benchmark FIND_CONNECTED_USERS_ONLINE")
ax1.grid(True, linestyle="--", alpha=0.6)

# Legenda combinata
lines1, labels1 = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax1.legend(lines1 + lines2, labels1 + labels2, loc="best")

# Etichette X ruotate
ax1.set_xticks(range(len(etichette)))

# Imposta xlabel sull'asse principale
ax1.set_xlabel("Configurazione (Gruppi, Utenti per gruppo, Utenti totali)")

# Migliora layout
fig.tight_layout()

plt.show()

# %%
"""
🎯 Benchmark configurazione:
  Server URL (HTTP): http://127.0.0.1:8002
  Server Host (WebSocket): 127.0.0.1:8002
  Per cambiare, imposta BENCHMARK_SERVER_URL e BENCHMARK_SERVER_HOST

Using TEST_DATABASE_URL: postgresql://ruggine_user:ruggine_secure_password@localhost:5433/ruggine_test
🐳 Connecting to Docker server at: http://127.0.0.1:8002
test e2e::benchmark::mixed_workload_benchmark::mixed_workload_benchmark_tests::test_mixed_workload_benchmark has been running for over 60 seconds
✅ Creati 16800 utenti in 1200 gruppi tramite API alle 2025-09-11 17:32:41
🎯 Tutti i task avviati alle 2025-09-11 17:34:00 UTC, benchmark in corso per 130 secondi...
==============================
🏁 Parametri del benchmark
Numero di gruppi: 1200
Utenti che creano messaggi per gruppo: 2
Utenti che chiamano find not read + mark read per gruppo: 2
Utenti che chiamano find paginated per gruppo: 2
Utenti connessi al websocket (passivi) per gruppo: 7
Utenti connessi al websocket (attivi con mark read) per gruppo: 1
Durata del test (s): 130
Intervallo senders (ms): 30000 ± 5000
Intervallo not read readers (ms): 30000 ± 10000
Intervallo paginated readers (ms): 55000 ± 15000
==============================


📊 RISULTATI BENCHMARK MIXED WORKLOAD:
=== DURATA TEST: 397.1638413s ===
  📝 Messaggi creati: 5855
  🔍 Query messaggi non letti: 7743
  📄 Query messaggi paginati: 6695
  ✅ Operazioni mark as read: 10667
  🔌 Connessioni WebSocket passive: 8400
  🔌 Connessioni WebSocket attive: 1200
  📨 Mark as read da WebSocket: 3629
  ❌ Operazioni fallite: 0
  🎯 Operazioni totali: 34589
  📈 Ops/sec: 87.09
  📉 Failure rate: 0.00%
✅ Benchmark completato con successo!
"""
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from matplotlib.patches import Patch

# === Leggi i dati CPU, memoria e messaggi ===
df_cpu = pd.read_csv("cpu_usage_logs_max.csv", parse_dates=['timestamp'])
df_mem = pd.read_csv("memory_usage_logs_max.csv", parse_dates=['timestamp'])
df_msg = pd.read_csv("messages_for_cpu_usage_logs_max.csv", parse_dates=['sent_at_second'])

# Ordina per sicurezza
df_cpu = df_cpu.sort_values('timestamp')
df_mem = df_mem.sort_values('timestamp')
df_msg = df_msg.sort_values('sent_at_second')

fig, ax1 = plt.subplots(figsize=(12,6))

# === CPU usage come linea ===
ax1.plot(df_cpu['timestamp'], df_cpu['cpu_usage_percent'],
         color='tab:blue', label='CPU Usage (%)')
ax1.set_xlabel("Orario (HH:MM:SS)")
ax1.set_ylabel("CPU Usage (%)", color='tab:blue')
ax1.tick_params(axis='y', labelcolor='tab:blue')
ax1.xaxis.set_major_formatter(mdates.DateFormatter('%H:%M:%S'))

# === Memoria come seconda linea sullo stesso asse Y ===
ax1.plot(df_mem['timestamp'], df_mem['memory_usage_percent'],
         color='tab:green', linestyle='--', label='Memory Usage (%)')

# === Messaggi come scatter (asse destro) ===
ax2 = ax1.twinx()
ax2.scatter(df_msg['sent_at_second'], df_msg['message_count'],
            color='tab:orange', marker='s', s=80, label='Messaggi inviati')
ax2.set_ylabel("Messaggi inviati", color='tab:orange')
ax2.tick_params(axis='y', labelcolor='tab:orange')

# === Evidenzia le fasi ===
start_users = pd.to_datetime("2025-09-15 12:10:13").tz_localize("UTC")
end_users   = pd.to_datetime("2025-09-15 12:11:39").tz_localize("UTC")
end_ws      = pd.to_datetime("2025-09-15 12:13:07").tz_localize("UTC")
end_test    = df_cpu['timestamp'].max()  # ultimo timestamp disponibile

ax1.axvspan(start_users, end_users, color="green", alpha=0.2)
ax1.axvspan(end_users, end_ws, color="red", alpha=0.2)
ax1.axvspan(end_ws, end_test, color="purple", alpha=0.15)

# === Legenda combinata ===
handles1, labels1 = ax1.get_legend_handles_labels()
handles2, labels2 = ax2.get_legend_handles_labels()
extra = [
    Patch(facecolor='green', alpha=0.2, label='Creazione utenti e gruppi'),
    Patch(facecolor='red', alpha=0.2, label='Connessioni WebSocket'),
    Patch(facecolor='purple', alpha=0.15, label='Benchmark workload')
]
fig.legend(handles1+handles2+extra,
           labels1+labels2+["Creazione utenti","Connessioni WebSocket","Benchmark workload"],
           loc="upper right", bbox_to_anchor=(0.55,0.93))

plt.title("Consumo CPU, memoria e invio messaggi nel tempo (non uniform distributed)")
ax1.grid(True, linestyle="--", alpha=0.6)
fig.tight_layout()
plt.show()

# %%
"""
🎯 Benchmark configurazione:
  Server URL (HTTP): http://127.0.0.1:8002
  Server Host (WebSocket): 127.0.0.1:8002
  Per cambiare, imposta BENCHMARK_SERVER_URL e BENCHMARK_SERVER_HOST

Using TEST_DATABASE_URL: postgresql://ruggine_user:ruggine_secure_password@localhost:5433/ruggine_test
🐳 Connecting to Docker server at: http://127.0.0.1:8002
test e2e::benchmark::mixed_workload_benchmark::mixed_workload_benchmark_tests::test_mixed_workload_benchmark has been running for over 60 seconds
✅ Creati 16800 utenti in 1200 gruppi tramite API alle 2025-09-11 17:14:25
🎯 Tutti i task avviati alle 2025-09-11 17:15:46 UTC, benchmark in corso per 130 secondi...
==============================
🏁 Parametri del benchmark
Numero di gruppi: 1200
Utenti che creano messaggi per gruppo: 2
Utenti che chiamano find not read + mark read per gruppo: 2
Utenti che chiamano find paginated per gruppo: 2
Utenti connessi al websocket (passivi) per gruppo: 7
Utenti connessi al websocket (attivi con mark read) per gruppo: 1
Durata del test (s): 130
Intervallo senders (ms): 30000 ± 30000
Intervallo not read readers (ms): 30000 ± 30000
Intervallo paginated readers (ms): 55000 ± 55000
==============================


📊 RISULTATI BENCHMARK MIXED WORKLOAD:
=== DURATA TEST: 430.0710369s ===
  📝 Messaggi creati: 6961
  🔍 Query messaggi non letti: 8494
  📄 Query messaggi paginati: 7103
  ✅ Operazioni mark as read: 11993
  🔌 Connessioni WebSocket passive: 8400
  🔌 Connessioni WebSocket attive: 1200
  📨 Mark as read da WebSocket: 4820
  ❌ Operazioni fallite: 0
  🎯 Operazioni totali: 39371
  📈 Ops/sec: 91.55
  📉 Failure rate: 0.00%
✅ Benchmark completato con successo!
SELECT
    date_trunc('second', sent_at AT TIME ZONE 'UTC') AS sent_at_second,
    COUNT(*) AS message_count
FROM text_message
GROUP BY sent_at_second
ORDER BY sent_at_second;
"""

import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from matplotlib.patches import Patch

# === Leggi i dati CPU, memoria e messaggi ===
df_cpu = pd.read_csv("cpu_usage_logs_uniform_distributed.csv", parse_dates=['timestamp'])
df_mem = pd.read_csv("memory_usage_logs_uniform_distributed.csv", parse_dates=['timestamp'])
df_msg = pd.read_csv("messages_for_cpu_usage_logs_uniform_distributed.csv", parse_dates=['sent_at_second'])

# Ordina per sicurezza
df_cpu = df_cpu.sort_values('timestamp')
df_mem = df_mem.sort_values('timestamp')
df_msg = df_msg.sort_values('sent_at_second')

fig, ax1 = plt.subplots(figsize=(12,6))

# === CPU usage come linea ===
ax1.plot(df_cpu['timestamp'], df_cpu['cpu_usage_percent'],
         color='tab:blue', label='CPU Usage (%)')
ax1.set_xlabel("Orario (HH:MM:SS)")
ax1.set_ylabel("CPU Usage (%)", color='tab:blue')
ax1.tick_params(axis='y', labelcolor='tab:blue')
ax1.xaxis.set_major_formatter(mdates.DateFormatter('%H:%M:%S'))

# === Memoria come seconda linea sullo stesso asse Y ===
ax1.plot(df_mem['timestamp'], df_mem['memory_usage_percent'],
         color='tab:green', linestyle='--', label='Memory Usage (%)')

# === Messaggi come scatter (asse destro) ===
ax2 = ax1.twinx()
ax2.scatter(df_msg['sent_at_second'], df_msg['message_count'],
            color='tab:orange', marker='s', s=80, label='Messaggi inviati')
ax2.set_ylabel("Messaggi inviati", color='tab:orange')
ax2.tick_params(axis='y', labelcolor='tab:orange')

# === Evidenzia le fasi ===
start_users = pd.to_datetime("2025-09-15 09:52:13").tz_localize("UTC")
end_users   = pd.to_datetime("2025-09-15 09:54:00").tz_localize("UTC")
end_ws      = pd.to_datetime("2025-09-15 09:55:30").tz_localize("UTC")
end_test    = df_cpu['timestamp'].max()  # ultimo timestamp disponibile

ax1.axvspan(start_users, end_users, color="green", alpha=0.2)
ax1.axvspan(end_users, end_ws, color="red", alpha=0.2)
ax1.axvspan(end_ws, end_test, color="purple", alpha=0.15)

# === Legenda combinata ===
handles1, labels1 = ax1.get_legend_handles_labels()
handles2, labels2 = ax2.get_legend_handles_labels()
extra = [
    Patch(facecolor='green', alpha=0.2, label='Creazione utenti e gruppi'),
    Patch(facecolor='red', alpha=0.2, label='Connessioni WebSocket'),
    Patch(facecolor='purple', alpha=0.15, label='Benchmark workload')
]
fig.legend(handles1+handles2+extra,
           labels1+labels2+["Creazione utenti","Connessioni WebSocket","Benchmark workload"],
           loc="upper right", bbox_to_anchor=(0.55,0.93))

plt.title("Consumo CPU, memoria e invio messaggi nel tempo (uniform distributed)")
ax1.grid(True, linestyle="--", alpha=0.6)
fig.tight_layout()
plt.show()
